# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


df = pd.read_csv('data_by_artist.csv')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28680 entries, 0 to 28679
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   mode              28680 non-null  int64
#  1   count             28680 non-null  int64
#  2   acousticness      28680 non-null  float64
#  3   artists           28680 non-null  object
#  4   danceability      28680 non-null  float64
#  5   duration_ms       28680 non-null  float64
#  6   energy            28680 non-null  float64
#  7   instrumentalness  28680 non-null  float64
#  8   liveness          28680 non-null  float64
#  9   loudness          28680 non-null  float64
#  10  speechiness       28680 non-null  float64
#  11  tempo             28680 non-null  float64
#  12  valence           28680 non-null  float64
#  13  popularity        28680 non-null  float64
#  14  key               28680 non-null  int64
# dtypes: float64(11), int64(3), object(1)
# ...

# %%
df.head()
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  250318.555556  0.394003          0.011400  0.290833 -14.448000
# 1  287280.000000  0.406808          0.081158  0.315215 -10.690000
# 2  328920.000000  0.286571          0.024593  0.325786 -15.230714
# 3  262890.962963  0.245770          0.073587  0.275481 -15.639370
# ...

# %%
df.sort_values(by=['loudness'], ascending=False)
# Out:
#        mode  count  acousticness                           artists  \
# 22600     0      2        0.0104                            Simian
# 24465     1      2        0.9250             The Calypso Orchestra
# 9098      1      1        0.9250                      Gerald Clark
# 20364     1      2        0.5090                     Ramesh Yaduan
# 5309      1      2        0.7160  Cyril Blake's Calypso Serenaders
# ...     ...    ...           ...                               ...
# 18314     1      2        0.9080                      Noise Makers
# 7913      0      2        0.9620                        Fabricants
# 9868      1      2        0.9080                        HI-FI CAMP
# 16241     0      2        0.9400                         Mark Biem
# 1776      0      2        0.0000                        Atlas Fret
#
#        danceability  duration_ms   energy  instrumentalness  liveness  \
# 22600         0.615     262773.0  0.97000             0.384     0.178
# ...

# %%
df.sort_values(by=['popularity'], ascending=False)
# Out:
#        mode  count  acousticness             artists  danceability  \
# 20966     0      2      0.056300         Ritt Momney      0.399000
# 14354     1      1      0.090700           Lele Pons      0.905000
# 15070     0      2      0.310000     Los Legendarios      0.823000
# 11764     1      2      0.819000            Jerry Di      0.854000
# 28263     1      2      0.424000         salem ilese      0.738000
# ...     ...    ...           ...                 ...           ...
# 22856     1      7      0.765429      Snehal Bhatkar      0.426571
# 22855     1      8      0.355000          Sneeky Dee      0.732500
# 10092     1      2      0.935000          Harry Wass      0.544000
# 10093     1      4      0.994500      Harsukh Kikani      0.703500
# 9309      1      2      0.987500  Giovanni Paisiello      0.596000
#
#          duration_ms    energy  instrumentalness  liveness   loudness  \
# 20966  210463.000000  0.491000          0.000890  0.110000 -10.778000
# ...

# %%
df_above_50 = df[df['count']>=50]
df_above_50.sort_values(by=['popularity'], ascending=False)
# Out:
#        mode  count  acousticness                                artists  \
# 10090     1     52      0.268816                           Harry Styles
# 2705      0     75      0.620989                          Billie Eilish
# 19880     1     52      0.221898                              Pop Smoke
# 15873     0     53      0.195461                                 Maluma
# 12799     1    184      0.206264                             Juice WRLD
# ...     ...    ...           ...                                    ...
# 6344      0    130      0.979762                      Dimitris Arapakis
# 25098     1     50      0.961760   The Liverpool Philharmonic Orchestra
# 9861      1    440      0.696323                         H.P. Lovecraft
# 18666     1    281      0.968434  Orchestra Sinfonica di Roma della RAI
# 16206     1     99      0.959162                            Mario Rossi
#
#        danceability    duration_ms    energy  instrumentalness  liveness  \
# ...

# %%
top_10_artists_df = df.sort_values(by=['count'], ascending=False).head(10)
df_plt = pd.DataFrame({'artist': top_10_artists_df['count'].values}, index = top_10_artists_df['artists'].values)

df_plt.plot.pie(y='artist',figsize=(12,12))
# Out:
# <AxesSubplot:ylabel='artist'>

# %%
df_artist_prolific = df[df['count'] >= 50]
df_artist_prolific.sort_values(by=['popularity'], ascending=False).head(10)
df_top_10_pop_artists = df_artist_prolific.sort_values(by=['popularity'], ascending=False).head(10)

df_correlated_features = df_top_10_pop_artists[['acousticness','danceability','energy',
                                                'instrumentalness','liveness','tempo','valence']].corr()

plt.figure(figsize=(12,8))
sns.heatmap(df_correlated_features, annot=True)
# Out:
# <AxesSubplot:>
