# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
df = pd.read_csv('linear_regression.csv')
df_values = df.values

X = df_values[:,0]
Y = df_values [:,1]
indices = list(range(0,11))
print(type(df))
print(type(df_values))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'numpy.ndarray'>

# %%
plt.plot(indices, X, 'o', color='black')

# %%
plt.plot(indices, Y, 'o', color='red')

# %%
plt.plot(indices, X, '--', color='black')
plt.plot(indices, Y, '--', color='red')

# %%
straight_line = [55 for i in range(11)]
plt.plot(indices, X, '--', color='black')
plt.plot(indices, straight_line, '--', color='red')
